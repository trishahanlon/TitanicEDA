# %%
#Trisha Moyer
# January 26, 2017


import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv("train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.describe()
# Out:
# /Users/tehanlon/anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000         NaN    0.000000
# 50%     446.000000    0.000000    3.000000         NaN    0.000000
# 75%     668.500000    1.000000    3.000000         NaN    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# ...

# %% [markdown]
# ## PassengerID
#
# 1. Continuous
# 2. No missing values
# 3. Mean, Max, Standard deviation
#   * Mean: 446
#   * Max: 891
#   * Standard deviation: 257.35384

# %%
df[df.PassengerId.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.PassengerId.value_counts()
# Out:
# 891    1
# 293    1
# 304    1
# 303    1
# 302    1
# 301    1
# 300    1
# 299    1
# 298    1
# 297    1
# 296    1
# 295    1
# 294    1
# 292    1
# 306    1
# 291    1
# 290    1
# 289    1
# 288    1
# 287    1
# 286    1
# 285    1
# 284    1
# 283    1
# 282    1
# 281    1
# 305    1
# 307    1
# 279    1
# 321    1
#       ..
# 561    1
# 560    1
# 584    1
# 585    1
# 586    1
# 587    1
# 610    1
# 609    1
# 608    1
# 607    1
# 606    1
# 605    1
# 604    1
# 603    1
# 602    1
# 601    1
# 600    1
# 599    1
# 598    1
# 597    1
# 596    1
# 595    1
# 594    1
# 593    1
# 592    1
# 591    1
# 590    1
# 589    1
# 588    1
# 1      1
# Name: PassengerId, dtype: int64

# %% [markdown]
# ## Survived
#
# 1. Categorical
# 2. No missing values
# 3. No max, mean, standard devation, not continuous

# %%
df[df.Survived.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.Survived.value_counts().plot(kind='barh', title="Survivors")

# %% [markdown]
# ## Pclass (Passenger class)
#
# 1. Categorical
# 2. No missing values
# 3. No Mean, Max, Standard deviation, categorical

# %%
df[df.Pclass.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.Pclass.hist(bins=5)

# %% [markdown]
# ## Sex
#
# 1. Categorical
# 2. No missing values
# 3. No Mean, Max, Standard deviation, categorical

# %%
df[df.Sex.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Sex=='male']
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 0              1         0       3                  Braund, Mr. Owen Harris
# 4              5         0       3                 Allen, Mr. William Henry
# 5              6         0       3                         Moran, Mr. James
# 6              7         0       1                  McCarthy, Mr. Timothy J
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 12            13         0       3           Saundercock, Mr. William Henry
# 13            14         0       3              Andersson, Mr. Anders Johan
# 16            17         0       3                     Rice, Master. Eugene
# 17            18         1       2             Williams, Mr. Charles Eugene
# 20            21         0       2                     Fynney, Mr. Joseph J
# 21            22         1       2                    Beesley, Mr. Lawrence
# ...

# %%
df[df.Sex=='female']
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 14            15         0       3
# 15            16         1       2
# 18            19         0       3
# 19            20         1       3
# 22            23         1       3
# 24            25         0       3
# 25            26         1       3
# 28            29         1       3
# 31            32         1       1
# 32            33         1       3
# 38            39         0       3
# 39            40         1       3
# 40            41         0       3
# 41            42         0       2
# 43            44         1       2
# 44            45         1       3
# 47            48         1       3
# 49            50         0       3
# ...

# %%
df.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df.Sex.value_counts().plot(kind='barh')

# %% [markdown]
# ## Age
#
# 1. Continuous
# 2. Yes, missing values
# 3.  Mean, Max, Standard deviation
#   * Mean: 29.699118
#   * Max: 80
#   * Standard deviation: 14.526497

# %%
df[df.Age.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
df.Age.hist()

# %% [markdown]
# ## SibSp (Siblings/Spouses aboard)
#
# 1. Continuous
# 2. No missing values
# 3.  Mean, Max, Standard deviation
#   * Mean: 0.523008
#   * Max: 8
#   * Standard deviation: 1.102743

# %%
df[df.SibSp.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.SibSp.hist(bins=5)

# %%
df.SibSp.value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
df.SibSp.value_counts().plot(kind='barh')

# %% [markdown]
# ## Parch (parents/children aboard)
#
# 1. Continuous
# 2. No missing values
# 3. Mean, Max, Standard deviation
#   * Mean: 0.381594
#   * Max: 6
#   * Standard deviation: 0.806057

# %%
df[df.Parch.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.Parch.hist(bins=10)

# %%
df.Parch.value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64

# %%
df.Parch.value_counts().plot(kind='bar')

# %% [markdown]
# ## Ticket
#
# 1. Categorical
# 2. No missing values
# 3. No Mean, Max, Standard deviation - Categorical

# %%
df[df.Ticket.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.Ticket.value_counts()
# Out:
# CA. 2343             7
# 347082               7
# 1601                 7
# 3101295              6
# 347088               6
# CA 2144              6
# 382652               5
# S.O.C. 14879         5
# 113781               4
# 347077               4
# 19950                4
# LINE                 4
# PC 17757             4
# 349909               4
# 2666                 4
# 17421                4
# 113760               4
# W./C. 6608           4
# 4133                 4
# PC 17582             3
# 110152               3
# PC 17760             3
# 345773               3
# C.A. 34651           3
# 29106                3
# 371110               3
# 347742               3
# 110413               3
# 35273                3
# 230080               3
#                     ..
# 36967                1
# 345767               1
# 349244               1
# 330923               1
# 349219               1
# 348124               1
# STON/O 2. 3101274    1
# 349246               1
# 113501               1
# ...

# %% [markdown]
# ## Fare
#
# 1. Continuous
# 2. No missing values
# 3. Mean, Max, Standard deviation
#   * Mean: 32.204208
#   * Max: 512.329200
#   * Standard deviation: 49.693429

# %%
df[df.Fare.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.Fare.hist(bins=5)

# %% [markdown]
# ## Cabin
#
# 1. Categorical
# 2. Missing Data
# 3. No Mean, Max, Standard deviation

# %%
df[df.Cabin.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 5              6         0       3
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 22            23         1       3
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 30            31         0       1
# 32            33         1       3
# 33            34         0       2
# ...

# %%
df.Cabin.value_counts()
# Out:
# B96 B98            4
# C23 C25 C27        4
# G6                 4
# F33                3
# F2                 3
# C22 C26            3
# E101               3
# D                  3
# C52                2
# C126               2
# B58 B60            2
# C2                 2
# E44                2
# D17                2
# B35                2
# D33                2
# E25                2
# B57 B59 B63 B66    2
# B20                2
# E8                 2
# E33                2
# B49                2
# B51 B53 B55        2
# C78                2
# C125               2
# B18                2
# C92                2
# F G73              2
# C93                2
# E24                2
#                   ..
# C82                1
# C95                1
# B94                1
# B73                1
# B101               1
# T                  1
# E68                1
# C106               1
# B4                 1
# F E69              1
# D19                1
# E12                1
# ...

# %%
df.Cabin.value_counts().plot(kind='barh')

# %% [markdown]
# ## Embarked
#
# 1. Categorical
# 2. Missing Data
# 3. No Mean, Max, Standard deviation

# %%
df[df.Embarked.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
df.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df.Embarked.value_counts().plot(kind='barh')
